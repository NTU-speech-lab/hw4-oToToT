# %%
import matplotlib.pyplot as plt

# %%
log = '''[ Epoch1: 1172/1172 ] loss:0.691 acc:55.357 
Train | Loss:0.69734 Acc: 49.835
Valid | Loss:0.69315 Acc: 50.134 
saving model with acc 50.134
-----------------------------------------------
[ Epoch2: 1172/1172 ] loss:0.565 acc:71.429 
Train | Loss:0.60603 Acc: 62.186
Valid | Loss:0.44995 Acc: 79.294 
saving model with acc 79.294
-----------------------------------------------
[ Epoch3: 1172/1172 ] loss:0.404 acc:79.464 
Train | Loss:0.43351 Acc: 80.138
Valid | Loss:0.42244 Acc: 80.059 
saving model with acc 80.059
-----------------------------------------------
[ Epoch4: 1172/1172 ] loss:0.507 acc:81.250 
Train | Loss:0.40098 Acc: 81.952
Valid | Loss:0.40122 Acc: 81.216 
saving model with acc 81.216
-----------------------------------------------

start training, parameter total:44236829, trainable:16347329

[ Epoch1: 2093/2093 ] loss:0.251 acc:90.476 
Train | Loss:0.21875 Acc: 90.502
Valid | Loss:0.39201 Acc: 82.511 
saving model with acc 82.511
-----------------------------------------------
[ Epoch2: 2093/2093 ] loss:0.174 acc:94.048 
Train | Loss:0.20266 Acc: 91.190
Valid | Loss:0.39585 Acc: 82.535 
saving model with acc 82.535
-----------------------------------------------
[ Epoch3: 2093/2093 ] loss:0.122 acc:92.857  
Train | Loss:0.18310 Acc: 92.168
Valid | Loss:0.40883 Acc: 81.929 
-----------------------------------------------
[ Epoch4: 2093/2093 ] loss:0.115 acc:96.429 
Train | Loss:0.15936 Acc: 93.349
Valid | Loss:0.42550 Acc: 82.005 
-----------------------------------------------

start training, parameter total:44236829, trainable:16347329

[ Epoch1: 2922/2922 ] loss:0.022 acc:100.000 
Train | Loss:0.09848 Acc: 96.080
Valid | Loss:0.53676 Acc: 81.819 
-----------------------------------------------
[ Epoch2: 2922/2922 ] loss:0.074 acc:93.478  
Train | Loss:0.08404 Acc: 96.729
Valid | Loss:0.59141 Acc: 81.478 
-----------------------------------------------
[ Epoch3: 2922/2922 ] loss:0.083 acc:97.826  
Train | Loss:0.07098 Acc: 97.295
Valid | Loss:0.59028 Acc: 81.142 
-----------------------------------------------
[ Epoch4: 2922/2922 ] loss:0.025 acc:100.000 
Train | Loss:0.06007 Acc: 97.756
Valid | Loss:0.63518 Acc: 80.960 
-----------------------------------------------

start training, parameter total:44236829, trainable:16347329

[ Epoch1: 3668/3668 ] loss:0.099 acc:96.154  
Train | Loss:0.04491 Acc: 98.338
Valid | Loss:0.64749 Acc: 80.768 
-----------------------------------------------
[ Epoch2: 3668/3668 ] loss:0.020 acc:100.000 
Train | Loss:0.03984 Acc: 98.536
Valid | Loss:0.71198 Acc: 81.044 
-----------------------------------------------
[ Epoch3: 3668/3668 ] loss:0.005 acc:100.000 
Train | Loss:0.03540 Acc: 98.717
Valid | Loss:0.72542 Acc: 81.012 
-----------------------------------------------
[ Epoch4: 3668/3668 ] loss:0.155 acc:96.154  
Train | Loss:0.03284 Acc: 98.807
Valid | Loss:0.75777 Acc: 80.862 
-----------------------------------------------

start training, parameter total:44236829, trainable:16347329

[ Epoch1: 4339/4339 ] loss:0.067 acc:94.828  
Train | Loss:0.02875 Acc: 98.971
Valid | Loss:0.85127 Acc: 80.788 
-----------------------------------------------
[ Epoch2: 4339/4339 ] loss:0.019 acc:100.000 
Train | Loss:0.02536 Acc: 99.089
Valid | Loss:0.81706 Acc: 80.713 
-----------------------------------------------
[ Epoch3: 4339/4339 ] loss:0.063 acc:98.276  
Train | Loss:0.02502 Acc: 99.111
Valid | Loss:0.83024 Acc: 81.134 
-----------------------------------------------
[ Epoch4: 4339/4339 ] loss:0.014 acc:100.000 
Train | Loss:0.02235 Acc: 99.225
Valid | Loss:0.94783 Acc: 80.409 
-----------------------------------------------'''

# %%
train_loss, valid_loss = [], []
train_acc, valid_acc = [], []

logs = log.split('\n')
for line in logs:
    if line[:len('Train |')] == 'Train |':
        acc_pos = line.find('Acc:')
        loss_pos = line.find('Loss:')
        acc = float(line[acc_pos + len('Acc:'):])
        loss = float(line[loss_pos + len('Loss:'):acc_pos])
        train_acc.append(acc)
        train_loss.append(loss)
    elif line[:len('Valid |')] == 'Valid |':
        acc_pos = line.find('Acc:')
        loss_pos = line.find('Loss:')
        acc = float(line[acc_pos + len('Acc:'):])
        loss = float(line[loss_pos + len('Loss:'):acc_pos])
        valid_acc.append(acc)
        valid_loss.append(loss)

# %%
epochs = list(range(1, len(train_loss) + 1))
losses = list(zip(train_loss, valid_loss))
accs = list(zip(train_acc, valid_acc))

# %%
plt.xticks(epochs)
plots = plt.plot(epochs, losses)
plt.legend(plots, ('training loss', 'validation loss'), loc='best')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.savefig('loss.pdf')
plt.show()

# %%
plt.xticks(epochs)
plots = plt.plot(epochs, accs)
plt.legend(plots, ('training accuracy', 'validation accuracy'), loc='best')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.savefig('acc.pdf')
plt.show()
